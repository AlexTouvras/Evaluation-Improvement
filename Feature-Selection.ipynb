# %% [markdown]
# # Excersice 4
#
# Feature selection:
#
# 1. You need to load the UCI Arrhythmia dataset
# https://archive.ics.uci.edu/ml/datasets/arrhythmia
# * the problem is a multi-class classification
#
# 2. For comparing the result you need to use kNN (k=3), and compare based on the accuracy with the original dataset (with the all features).
#
# 2. Run three different types of feature selection methods (Univariate Statistics, model based, and Iterative Feature Selection).
# * The original data set has 279 features.
# * You need to run the methods for number_of_features= 20, 50, 100, 150, 200
# * All the results should show in the same figure (At the end we have just one figure)

# %%
! git add -A
# Out:
# fatal: Unable to create 'C:/Users/alext/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedWriter name=9>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=10>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=11>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# warning: could not open directory 'AppData/Local/Application Data/': Permission denied
# warning: could not open directory 'AppData/Local/ElevatedDiagnostics/': Permission denied
# warning: could not open directory 'AppData/Local/History/': Permission denied
# warning: could not open directory 'AppData/Local/Microsoft/Windows/INetCache/Content.IE5/': Permission denied
# warning: could not open directory 'AppData/Local/Microsoft/Windows/Temporary Internet Files/': Permission denied
# warning: could not open directory 'AppData/Local/Temp/msdtadmin/': Permission denied
# warning: could not open directory 'AppData/Local/Temporary Internet Files/': Permission denied
# warning: could not open directory 'Application Data/': Permission denied
# warning: could not open directory 'Cookies/': Permission denied
# warning: could not open directory 'Documents/My Music/': Permission denied
# warning: could not open directory 'Documents/My Pictures/': Permission denied
# warning: could not open directory 'Documents/My Videos/': Permission denied
# warning: could not open directory 'Local Settings/': Permission denied
# warning: could not open directory 'My Documents/': Permission denied
# warning: could not open directory 'NetHood/': Permission denied
# warning: could not open directory 'PrintHood/': Permission denied
# warning: could not open directory 'Recent/': Permission denied
# warning: could not open directory 'SendTo/': Permission denied
# warning: could not open directory 'Start Menu/': Permission denied
# warning: could not open directory 'Templates/': Permission denied
# warning: LF will be replaced by CRLF in .anaconda/navigator/.anaconda/navigator/metadata/metadata.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .anaconda/navigator/.anaconda/navigator/scripts/notebook.bat.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .anaconda/navigator/.anaconda/navigator/scripts/spyder.bat.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .anaconda/navigator/scripts/anaconda-navigator-app.bat.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .bash_history.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .git-credentials.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .gitconfig.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .ipynb_checkpoints/Untitled1-checkpoint.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .ipython/profile_default/startup/README.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .lesshst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .spyder-py3/history.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .viminfo.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/argv.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/.eslintignore.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/.vsixmanifest.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/CHANGELOG.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/README.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/SECURITY.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/SUPPORT.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/ThirdPartyNotices-Distribution.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/ThirdPartyNotices-Repository.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/cgmanifest.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/dist/extension.browser.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/experiments.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/jedils_requirements.in.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/jedils_requirements.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/languages/pip-requirements.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/extension.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/azure-storage.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/diff-match-patch.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/node-stream-zip.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/request-progress.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/request.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/source-map-support.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/sudo-prompt.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Ll.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Lm.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Lo.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Lt.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Lu.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Mc.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Mn.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Nd.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Nl.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/unicode/category/Pc.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/node_modules/xml2js.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/out/client/package.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.de.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.es.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.fr.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.it.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.ja.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.ko-kr.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.nl.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.pl.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.pt-br.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.ru.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.tr.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.zh-cn.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/package.nls.zh-tw.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/.env.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/.vscode/settings.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/Notebooks intro.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/install_debugpy.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/interpreterInfo.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/README.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/bin/jedi-language-server.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/dataclasses.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/docstring_to_markdown/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/docstring_to_markdown/rst.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/importlib_metadata/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/importlib_metadata/_collections.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/importlib_metadata/_compat.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/importlib_metadata/_functools.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/importlib_metadata/_itertools.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/__main__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/_compatibility.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/classes.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/completion.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/completion_cache.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/environment.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/errors.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/exceptions.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/file_name.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/helpers.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/interpreter.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/keywords.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/project.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/refactoring/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/refactoring/extract.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/replstartup.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/api/strings.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/cache.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/common.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/debug.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/file_io.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/analysis.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/arguments.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/base_value.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/cache.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/access.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/getattr_static.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/mixed.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/subprocess/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/subprocess/__main__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/subprocess/functions.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/compiled/value.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/context.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/docstrings.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/dynamic_params.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/filters.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/finder.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/flow_analysis.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/annotation.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/base.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/conversion.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/generics.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/stub_value.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/type_var.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/typeshed.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/typing.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/gradual/utils.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/helpers.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/imports.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/lazy_value.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/names.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/param.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/parser_cache.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/recursion.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/references.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/signature.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/star_args.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/syntax_tree.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/sys_path.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/utils.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/decorator.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/dynamic_arrays.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/function.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/instance.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/iterable.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/klass.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/module.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/inference/value/namespace.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/parser_utils.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/__init__.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/django.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/flask.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/pytest.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/registry.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/plugins/stdlib.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/settings.py.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/apps/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/apps/config.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/apps/registry.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/global_settings.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/locale/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/urls/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/urls/i18n.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/conf/urls/static.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/actions.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/apps.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/checks.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/decorators.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/filters.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/forms.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/helpers.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/models.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/options.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/sites.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_list.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_modify.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_static.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/admin_urls.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/base.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/log.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/tests.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/utils.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/autocomplete.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/decorators.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/main.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admin/widgets.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admindocs/middleware.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admindocs/urls.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admindocs/utils.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/admindocs/views.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/__init__.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/admin.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/apps.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/backends.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/base_user.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/checks.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/context_processors.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/decorators.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/forms.pyi.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-python.python-2021.10.1365161279/pythonFiles/lib/jedilsp/jedi/third_party/django-stubs/django-stubs/contrib/auth/handlers/modwsgi.pyi.
# The file will have its original line endings in your working directory
# ...
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/resources/light/restart-kernel.svg.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/resources/light/runabove.svg.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/resources/light/runbelow.svg.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/resources/light/variable_explorer.svg.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/snippets/python.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/vscode.d.ts.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/vscode.proposed.d.ts.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-keymap-1.0.0/.vsixmanifest.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-keymap-1.0.0/package.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/.nvmrc.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/.vsixmanifest.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/CHANGELOG.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/NOTICE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/README.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/SECURITY.md.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/gulpfile.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/275.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/396.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/396.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/644.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/644.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/dataresource.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/dataresource.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/geojson.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/geojson.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/modeldebug.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/nteract_transforms.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/nteract_transforms.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/nteract_transforms_vsdom.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/nteract_transforms_vsdom.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/plotly.bundle.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/plotly.bundle.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/renderers.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/client_renderer/renderers.js.LICENSE.txt.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/out/extension_renderer/index.js.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in .vscode/extensions/ms-toolsai.jupyter-renderers-1.0.3/package.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/BackgroundAgent.20211014.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/BackgroundAgent.20211021.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/BackgroundAgent.20211022.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/BackgroundAgent.20211027.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180921_110858_460000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180923_170946_928000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180924_000948_655000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180925_000930_371000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180926_100705_406000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20180927_000640_393000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20181001_100015_400000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20181002_101613_466000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20181005_201634_260000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/ccd.20181008_224407_597000.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/special_logs/CCDLogin.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/AOP SDK/acer infra/acer/SyncAgent/logs/ccd/special_logs/CCDStart.log.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/AdobeUpdaterPrefs.dat.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/CSUTracker.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/Data/AdobeApplicationManager-1.0/update14/update14.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/Data/AdobeExportAssets264bit-2.0/2.4/2.4.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/Data/AdobePhotoshopCC2015-16.0/16.1.2/16.1.2.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/Data/AdobePreviewCC-1.0.0/1.1.3/1.1.3.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/AAMUpdater/1.0/Data/PhotoshopCameraRaw8-8.0/10.0.92/10.0.92.xml.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeCMapFnt17.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeCMapFnt18.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeCMapFnt19.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeCMapFnt20.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeCMapFnt21.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeSysFnt17.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeSysFnt18.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeSysFnt19.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeSysFnt20.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/AdobeSysFnt21.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/Cache/AcroFnt17.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/Cache/AcroFnt18.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/Cache/AcroFnt19.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/Cache/AcroFnt20.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Adobe/Acrobat/DC/Cache/AcroFnt21.lst.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Blizzard Entertainment/System Survey/ProductData/WoW/Game.index.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Blizzard Entertainment/System Survey/ProductData/WoW/Game/addons.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/Blizzard Entertainment/System Survey/ProductData/WoW/Game/vars.json.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in AppData/Local/CEF/User Data/WidevineCDM/1.4.8.903/manifest.json.
# The file will have its original line endings in your working directory
# error: open("AppData/Local/Comms/UnistoreDB/USS.jtx"): Permission denied
# error: unable to index file 'AppData/Local/Comms/UnistoreDB/USS.jtx'
# fatal: adding files failed
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedWriter name=6>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=7>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\threading.py:914: ResourceWarning: unclosed file <_io.BufferedReader name=8>
#   del self._target, self._args, self._kwargs
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
! git commit -am "Task 2"

# %%
! git push

# %%
import pandas as pd
import numpy as np
# Put the dataset into a dataframe
arrhythmia_data =  pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/arrhythmia/arrhythmia.data", header=None)
# dtypes for our columns
arrhythmia_data.dtypes
# Out:
# 0        int64
# 1        int64
# 2        int64
# 3        int64
# 4        int64
#         ...
# 275    float64
# 276    float64
# 277    float64
# 278    float64
# 279      int64
# Length: 280, dtype: object

# %%
# Descriptive statistics of the DataFrame
arrhythmia_data.describe().transpose().head(50)
# Out:
#     count        mean        std    min     25%    50%    75%    max
# 0   452.0   46.471239  16.466631    0.0   36.00   47.0   58.0   83.0
# 1   452.0    0.550885   0.497955    0.0    0.00    1.0    1.0    1.0
# 2   452.0  166.188053  37.170340  105.0  160.00  164.0  170.0  780.0
# 3   452.0   68.170354  16.590803    6.0   59.00   68.0   79.0  176.0
# 4   452.0   88.920354  15.364394   55.0   80.00   86.0   94.0  188.0
# 5   452.0  155.152655  44.842283    0.0  142.00  157.0  175.0  524.0
# 6   452.0  367.207965  33.385421  232.0  350.00  367.0  384.0  509.0
# 7   452.0  169.949115  35.633072  108.0  148.00  162.0  179.0  381.0
# 8   452.0   90.004425  25.826643    0.0   79.00   91.0  102.0  205.0
# 9   452.0   33.676991  45.431434 -172.0    3.75   40.0   66.0  169.0
# 15  452.0    5.628319  10.650001    0.0    0.00    0.0   12.0   88.0
# 16  452.0   51.628319  18.249901    0.0   40.00   48.0   60.0  156.0
# 17  452.0   20.920354  20.541728    0.0    0.00   20.0   36.0   88.0
# 18  452.0    0.141593   1.569483    0.0    0.00    0.0    0.0   24.0
# 19  452.0    0.000000   0.000000    0.0    0.00    0.0    0.0    0.0
# 20  452.0   30.035398  10.046393    0.0   24.00   28.0   36.0  100.0
# 21  452.0    0.002212   0.047036    0.0    0.00    0.0    0.0    1.0
# 22  452.0    0.011062   0.104708    0.0    0.00    0.0    0.0    1.0
# 23  452.0    0.011062   0.104708    0.0    0.00    0.0    0.0    1.0
# 24  452.0    0.004425   0.066445    0.0    0.00    0.0    0.0    1.0
# 25  452.0    0.004425   0.066445    0.0    0.00    0.0    0.0    1.0
# 26  452.0    0.008850   0.093759    0.0    0.00    0.0    0.0    1.0
# 27  452.0    5.619469  11.220680    0.0    0.00    0.0    0.0   76.0
# 28  452.0   54.336283  17.248213    0.0   44.00   48.0   64.0  132.0
# 29  452.0   20.592920  21.061050    0.0    0.00   20.0   36.0   92.0
# 30  452.0    0.433628   3.093161    0.0    0.00    0.0    0.0   36.0
# 31  452.0    0.150442   2.692591    0.0    0.00    0.0    0.0   56.0
# 32  452.0   31.637168   9.624951    0.0   24.00   28.0   36.0   76.0
# 33  452.0    0.017699   0.132002    0.0    0.00    0.0    0.0    1.0
# 34  452.0    0.028761   0.167319    0.0    0.00    0.0    0.0    1.0
# 35  452.0    0.002212   0.047036    0.0    0.00    0.0    0.0    1.0
# 36  452.0    0.004425   0.066445    0.0    0.00    0.0    0.0    1.0
# 37  452.0    0.004425   0.066445    0.0    0.00    0.0    0.0    1.0
# 38  452.0    0.015487   0.123615    0.0    0.00    0.0    0.0    1.0
# 39  452.0   16.026549  21.906457    0.0    0.00    0.0   28.0   92.0
# 40  452.0   41.982301  23.106034    0.0   27.00   40.0   56.0  116.0
# 41  452.0   20.327434  25.365424    0.0    0.00    0.0   40.0  132.0
# 42  452.0    2.300885   9.212818    0.0    0.00    0.0    0.0   64.0
# 43  452.0    0.318584   3.124229    0.0    0.00    0.0    0.0   44.0
# 44  452.0   30.513274  18.359850    0.0   16.00   28.0   44.0   92.0
# 45  452.0    0.002212   0.047036    0.0    0.00    0.0    0.0    1.0
# 46  452.0    0.035398   0.184989    0.0    0.00    0.0    0.0    1.0
# 47  452.0    0.002212   0.047036    0.0    0.00    0.0    0.0    1.0
# 48  452.0    0.017699   0.132002    0.0    0.00    0.0    0.0    1.0
# 49  452.0    0.011062   0.104708    0.0    0.00    0.0    0.0    1.0
# 50  452.0    0.004425   0.066445    0.0    0.00    0.0    0.0    1.0
# 51  452.0   45.362832  24.813651    0.0   40.00   48.0   56.0  136.0
# 52  452.0   19.327434  17.388960    0.0    0.00   20.0   32.0   80.0
# 53  452.0    7.796460  18.365908    0.0    0.00    0.0    0.0   80.0
# 54  452.0    2.823009  10.319705    0.0    0.00    0.0    0.0   84.0

# %% [markdown]
# We can see that 275 columns were printed, but we have 280 columns (279 features plus the label). There is an issue with 5 columns.

# %%
# check to see if there are any columns with missing values 
arrhythmia_data.columns[arrhythmia_data.isnull().any()].tolist()
# Out:
# []

# %%
# Check to see whether any column is an object.
arrhythmia_data.loc[:, arrhythmia_data.dtypes == object]
# Out:
#       10   11   12   13  14
# 0     13   64   -2    ?  63
# 1     37  -17   31    ?  53
# 2     34   70   66   23  75
# 3     11   -5   20    ?  71
# 4     13   61    3    ?   ?
# ..   ...  ...  ...  ...  ..
# 447    4   40  -27    ?  63
# 448   66   52   79    ?  73
# 449  -19  -61  -70   84  84
# 450   29  -22   43  103  80
# 451   79   52   47    ?  75
#
# [452 rows x 5 columns]

# %%
question_columns = arrhythmia_data.loc[:, arrhythmia_data.dtypes == object].columns
print("Count the occurence of ? per column:")
for col in question_columns:
    print("Column {:.0f} has {:.0f} '?' occurence(s).".format(col, arrhythmia_data[col].str.contains(r'[?]').sum()))
# Out:
# Count the occurence of ? per column:
# Column 10 has 8 '?' occurence(s).
# Column 11 has 22 '?' occurence(s).
# Column 12 has 1 '?' occurence(s).
# Column 13 has 376 '?' occurence(s).
# Column 14 has 1 '?' occurence(s).

# %% [markdown]
# There are five columns that contain missing values. One column has missing variables above 50%. The rest 4 columns have lower amounts of missing values.

# %%
#switch ? for NaN
arrhythmia_data[arrhythmia_data=='?'] = np.NaN
#drop columns with more than 50% NaN
arrhythmia_data.dropna(axis=1, thresh=arrhythmia_data.index.size*0.5, inplace=True)
#drop rows with NaN values
arrhythmia_data.dropna(axis=0, inplace=True)

# %%
X = arrhythmia_data.iloc[: , :278]
y = arrhythmia_data[279].astype(str).astype(int)
X.shape
# Out:
# (420, 278)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# Our benchmark model
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# scale the dataset to have mean equal to 0 and std equal to 1
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
KNN = KNeighborsClassifier(n_neighbors=3)
KNN.fit(X_train_scaled, y_train)
print("Training set score: {:.3f}".format(KNN.score(X_train_scaled, y_train)))
print("Test set score: {:.3f}".format(KNN.score(X_test_scaled, y_test)))
# Out:
# Training set score: 0.708
# Test set score: 0.533

# %%
# Utility function to report best scores

def report(results, n_top=5):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})"
                  .format(results['mean_test_score'][candidate],
                          results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
from sklearn.feature_selection import SelectKBest, SelectFromModel, RFE
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from time import time
import warnings
#warnings.filterwarnings("ignore")
warnings.resetwarnings()
pipe = Pipeline([
  ('scaler', StandardScaler()),
  ('feature_selection', SelectKBest()),
  ('classification', KNeighborsClassifier(n_neighbors=3,n_jobs=-1))
])

# specify parameters and distributions to sample from
param_grid = [
     {'classification': [KNeighborsClassifier(n_neighbors=3,n_jobs=-1)]},
    
     {'feature_selection': [SelectKBest()],
     'feature_selection__k':[20, 50, 100, 150, 200]},

     {'feature_selection': [SelectFromModel(LogisticRegression(random_state=42), threshold=-np.inf)],
     'feature_selection__max_features':[20, 50, 100, 150, 200]},
    
     {'feature_selection': [RFE(LogisticRegression(random_state=42))],
     'feature_selection__n_features_to_select':[20, 50, 100, 150, 200]}

]

# run randomized search
grid_search = GridSearchCV(pipe, param_grid, n_jobs = -1)

start = time()
grid_search.fit(X, y)
report(grid_search.cv_results_)
stop = time()
# Out:
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Model with rank: 1
# Mean validation score: 0.714 (std: 0.021)
# Parameters: {'feature_selection': SelectKBest(k=50), 'feature_selection__k': 50}
#
# Model with rank: 2
# Mean validation score: 0.693 (std: 0.020)
# Parameters: {'feature_selection': RFE(estimator=LogisticRegression(random_state=42)), 'feature_selection__n_features_to_select': 50}
#
# Model with rank: 3
# Mean validation score: 0.683 (std: 0.035)
# Parameters: {'feature_selection': RFE(estimator=LogisticRegression(random_state=42)), 'feature_selection__n_features_to_select': 20}
#
# Model with rank: 4
# Mean validation score: 0.674 (std: 0.014)
# Parameters: {'feature_selection': SelectFromModel(estimator=LogisticRegression(random_state=42), threshold=-inf), 'feature_selection__max_features': 50}
#
# Model with rank: 5
# Mean validation score: 0.674 (std: 0.027)
# Parameters: {'feature_selection': SelectKBest(k=50), 'feature_selection__k': 20}
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:112: UserWarning: Features [ 18  20  66  68  70  82  83 130 131 138 140 142 144 150 155 156 163 203
#  263 273] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# C:\Users\alext\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %%
print("gridSearchCV took %.2f seconds" % ((stop - start)))
import mglearn
selection_method = ["SelectKBest", "SelectFromModel", "RFE", "Benchmark"]
method = [20, 50, 100, 150, 200, "all"]
results = pd.DataFrame(grid_search.cv_results_)
scores = np.array(results.iloc[-15:].mean_test_score).reshape(3,5)
# some manipulation to add benchmark score to the same array
column_to_be_added = np.array([np.NaN, np.NaN, np.NaN, np.NaN, np.NaN, results.mean_test_score[0]])
final = np.empty((3,6))
final[:] = np.NaN
final[:,:-1] = scores
# Adding benchmark row to numpy array
scores = np.vstack([final, column_to_be_added])
# plot the mean cross-validation scores
mglearn.tools.heatmap(scores, xlabel='n_features', xticklabels=method,
ylabel='method', yticklabels=selection_method, cmap="viridis")
# Out:
# gridSearchCV took 234.02 seconds
